# %%
import pandas as pd

# %%
#df_1 = pd.read(r"C:\Users\yagmu\OneDrive\Desktop\FOLDERS\TÜBİTAK_2242\Baby Cry Sense Dataset\Baby Cry Dataset")
#df_2 = pd.read(r"C:\Users\yagmu\OneDrive\Desktop\FOLDERS\TÜBİTAK_2242\Donate-a-Cry Corpus\donateacry_corpus")    
#df_3 = pd.read(r"C:\Users\yagmu\OneDrive\Desktop\FOLDERS\TÜBİTAK_2242\Infant cry Dataset\Dataset")
#df_4 = pd.read(r"C:\Users\yagmu\OneDrive\Desktop\FOLDERS\TÜBİTAK_2242\Infants Cry Sound\Infants Cry Sound\Dataset")
